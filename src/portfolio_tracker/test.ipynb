# %%
import yfinance as yf
import pandas as pd

# %%
def get_price(ticker:str):
    ticker = ticker.upper() #Be sure that the ticker is all uppercase
    prices = yf.download(ticker, period="max", interval="1mo")
    print(prices.head())
    #removing the double column header 
    prices.columns = prices.columns.droplevel(1)
    print(prices.columns)
    
    adj_close_series = pd.Series(prices["Close"])
    print( adj_close_series.head())

# %%
get_price("bynd")
# Out:
# /tmp/ipykernel_1153/2045940330.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   prices = yf.download(ticker, period="max", interval="1mo")
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            BYND        BYND        BYND        BYND       BYND
# Date
# 2019-05-01  104.120003  105.250000   45.000000   46.000000  202729400
# 2019-06-01  160.679993  201.880005   95.662003  104.139999  224833600
# 2019-07-01  196.509995  239.710007  147.020004  161.490005  150169400
# 2019-08-01  167.630005  183.990005  136.270004  175.139999  112808600
# 2019-09-01  148.619995  169.309998  133.080002  167.630005   48794000
# Index(['Close', 'High', 'Low', 'Open', 'Volume'], dtype='object', name='Price')
# Date
# 2019-05-01    104.120003
# 2019-06-01    160.679993
# 2019-07-01    196.509995
# 2019-08-01    167.630005
# 2019-09-01    148.619995
# Name: Close, dtype: float64

# %%
import yfinance as yf

data = yf.download("AAPL", start="2023-01-01", end="2023-12-31")
print(data.head())
# Out:
# Failed to get ticker 'AAPL' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPL']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
import socket

try:
    socket.create_connection(("query1.finance.yahoo.com", 443), timeout=5)
    print("Connection OK")
except OSError as e:
    print("No connection:", e)
# Out:
# Connection OK

# %%
pip install --upgrade yfinance
# Out:
# WARNING: Ignoring invalid distribution -ygments (/opt/conda/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ygments (/opt/conda/lib/python3.8/site-packages)
# Requirement already satisfied: yfinance in /opt/conda/lib/python3.8/site-packages (0.2.37)
# Collecting yfinance
#   Downloading yfinance-0.2.66-py2.py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 KB 8.7 MB/s eta 0:00:00
# Collecting curl_cffi>=0.7
#   Downloading curl_cffi-0.9.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 9.4 MB/s eta 0:00:00:00:0100:01m
# Requirement already satisfied: pytz>=2022.5 in /opt/conda/lib/python3.8/site-packages (from yfinance) (2024.1)
# Requirement already satisfied: requests>=2.31 in /opt/conda/lib/python3.8/site-packages (from yfinance) (2.31.0)
# Collecting platformdirs>=2.0.0
#   Downloading platformdirs-4.3.6-py3-none-any.whl (18 kB)
# Requirement already satisfied: peewee>=3.16.2 in /opt/conda/lib/python3.8/site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/conda/lib/python3.8/site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/lib/python3.8/site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/conda/lib/python3.8/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: pandas>=1.3.0 in /opt/conda/lib/python3.8/site-packages (from yfinance) (1.4.2)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/conda/lib/python3.8/site-packages (from yfinance) (2.4.1)
# Requirement already satisfied: protobuf>=3.19.0 in /opt/conda/lib/python3.8/site-packages (from yfinance) (5.29.5)
# Collecting websockets>=13.0
#   Downloading websockets-13.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.3/164.3 KB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.8/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: cffi>=1.12.0 in /opt/conda/lib/python3.8/site-packages (from curl_cffi>=0.7->yfinance) (1.15.0)
# Collecting certifi>=2024.2.2
#   Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.4/159.4 KB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.8/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.8/site-packages (from requests>=2.31->yfinance) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests>=2.31->yfinance) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests>=2.31->yfinance) (1.26.9)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.8/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas>=1.3.0->yfinance) (1.16.0)
# WARNING: Ignoring invalid distribution -ygments (/opt/conda/lib/python3.8/site-packages)
# Installing collected packages: websockets, platformdirs, certifi, curl_cffi, yfinance
#   Attempting uninstall: certifi
#     WARNING: Ignoring invalid distribution -ygments (/opt/conda/lib/python3.8/site-packages)
#     Found existing installation: certifi 2021.10.8
#     Uninstalling certifi-2021.10.8:
#       Successfully uninstalled certifi-2021.10.8
#   Attempting uninstall: yfinance
#     WARNING: Ignoring invalid distribution -ygments (/opt/conda/lib/python3.8/site-packages)
#     Found existing installation: yfinance 0.2.37
#     Uninstalling yfinance-0.2.37:
#       Successfully uninstalled yfinance-0.2.37
# WARNING: Ignoring invalid distribution -ygments (/opt/conda/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ygments (/opt/conda/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ygments (/opt/conda/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ygments (/opt/conda/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ygments (/opt/conda/lib/python3.8/site-packages)
# Successfully installed certifi-2025.11.12 curl_cffi-0.9.0 platformdirs-4.3.6 websockets-13.1 yfinance-0.2.66
# WARNING: Ignoring invalid distribution -ygments (/opt/conda/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ygments (/opt/conda/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ygments (/opt/conda/lib/python3.8/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

data = yf.download("AAPL", start="2023-01-01", end="2023-02-01", auto_adjust=True)
print(data.head())
# Out:
# Failed to get ticker 'AAPL' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPL']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []
