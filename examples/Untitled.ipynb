# %%
import importlib, src.portfolio_tracker.transform as tf
importlib.reload(tf)
from src.portfolio_tracker.transform import daily_returns, portfolio_returns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 import importlib, src.portfolio_tracker.transform as tf
#       2 importlib.reload(tf)
#       3 from src.portfolio_tracker.transform import daily_returns, portfolio_returns
#
# ModuleNotFoundError: No module named 'src'
